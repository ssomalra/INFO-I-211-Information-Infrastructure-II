# %% [markdown]
# # Question 1
# Your biology professor has a pet project studying irises. They would like you to use the iris dataset from Seaborn to perform a thorough graphical analysis. Provide both the figures (in PNG format) and code for creating the following plots. (Be sure to make sure axes are labeled, figures have titles, and keys are included.)

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Part A:
# Look at the distributions for each trait (sepal length, sepal width, petal length, and petal width)

# %%
graph = sns.kdeplot(data=iris)
graph.set_title('Distributions of Iris Dataset')
graph.set_xlabel('Measurement (cm)')
# Out:
# Text(0.5, 0, 'Measurement (cm)')

# %% [markdown]
# ### Part B:
# Create a categorical plot for each trait by species

# %%
sns.boxplot(x='species', y='sepal_width', data=iris).set(title='Sepal Width Distributions by Species')
plt.show()
plt.close()
sns.boxplot(x='species', y='sepal_length', data=iris).set(title='Sepal Length Distributions by Species')
plt.show()
plt.close()
sns.boxplot(x='species', y='petal_length', data=iris).set(title='Petal Width Distributions by Species')
plt.show()
plt.close()
sns.boxplot(x='species', y='petal_width', data=iris).set(title='Petal Length Distributions by Species')
plt.show()
plt.close()

# %% [markdown]
# ### Part C
# Create relational plots between trait pairs (sepal length vs sepal width, petal length vs petal width), and include a way of distinguishing by species

# %%
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', 
                hue='species', style='species').set(title='Sepal Length vs Sepal Width')
plt.show()
plt.close()
sns.scatterplot(data=iris, x='petal_length', y='petal_width', 
                hue='species', style='species').set(title='Petal Length vs Petal Width')
plt.show()
plt.close()

# %% [markdown]
# ### Part D
# Based upon your analysis, which species are most related?

# %% [markdown]
# Versicolor and Virginia species are more closely related because according to the scatterplots, their traits are more clustered together compared to Setosa

# %% [markdown]
# # Question 2
# Your local gym is helping a nearby elementary school by providing diet and workout data for their various patrons. Import the exercise data from Seaborn. Provide both the figures (in PNG format) and code for creating the following plots.

# %%
exercise = sns.load_dataset('exercise')
exercise
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %% [markdown]
# ### Part A
# Create a heatmap for the participants, workout time, and pulse. (Hint use the pivot command from Pandas to get the data in appropriate format)

# %%
graph = exercise.pivot(columns='time', index='id', values='pulse')
graph
# Out:
# time  1 min  15 min  30 min
# id
# 1        85      85      88
# 2        90      92      93
# 3        97      97      94
# 4        80      82      83
# 5        91      92      91
# 6        83      83      84
# 7        87      88      90
# 8        92      94      95
# 9        97      99      96
# 10      100      97     100
# 11       86      86      84
# 12       93     103     104
# 13       90      92      93
# 14       95      96     100
# 15       89      96      95
# 16       84      86      89
# 17      103     109      90
# 18       92      96     101
# 19       97      98     100
# 20      102     104     103
# 21       93      98     110
# 22       98     104     112
# 23       98     105      99
# 24       87     132     120
# 25       94     110     116
# 26       95     126     143
# 27      100     126     140
# 28      103     124     140
# 29       94     135     130
# 30       99     111     150

# %%
sns.heatmap(graph).set(title='Heatmap for Participants, Workout Time, and Pulse')
# Out:
# [Text(0.5, 1.0, 'Heatmap for Participants, Workout Time, and Pulse')]

# %% [markdown]
# ### Part B
# Create a categorical plot for pulse by diet and by type of exercise

# %%
sns.swarmplot(x='kind', y='pulse', hue='diet', data=exercise).set(title='Distribution of Pulse by Diet and Type of Exercise')
# Out:
# [Text(0.5, 1.0, 'Distribution of Pulse by Diet and Type of Exercise')]

# %% [markdown]
# ### Part C
# Give a brief explanation of the meaning of the 3 graphs to the elementary students.

# %% [markdown]
# Participants who are resting have pulses that range between around 80-100bpm. Diet doesn't impact particpants too much.
#
# Participants who walk have pulses that range between about 85-110pm. Participants with no fat in their diet typically have higher pulses, but is still comparable to participants who have low fat in their diet.
#
# Finally, participants who run have pulses that range from around 90-150bpm. Participants who have no fat in their diet have much higher pulses (majority have pulses between around 120-150bpm) than those who have low fat in their diet (majority have pulses between around 90-120bpm)
